# %% [markdown]
# # PiML Outcome Analysis
#
# - Prediction Accuracy
#
# - Weakness Detection
#
# - Overfitting Analysis
#
# - Prediction Uncertainty
#
# - Robustness and Resilience
#
# - Bias and Fairness

# %%
# !pip install piml

# %% [markdown]
# ## 1) Example Data and Model

# %%
from piml import Experiment
exp = Experiment()
exp.data_loader(data="SimuCredit")
# Out:
# (CVXPY) Mar 20 03:13:06 AM: Encountered unexpected exception importing solver GLOP:
# RuntimeError('Unrecognized new version of ortools (9.7.2996). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')
# (CVXPY) Mar 20 03:13:06 AM: Encountered unexpected exception importing solver PDLP:
# RuntimeError('Unrecognized new version of ortools (9.7.2996). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')
#         Mortgage  Balance  Amount Past Due  Credit Inquiry  Open Trade  \
# 0      196153.90  2115.19             0.00               0           0
# 1      149717.49  2713.77          1460.57               1           1
# 2      292626.34  2209.01             0.00               0           0
# 3      264812.52    21.68             0.00               0           0
# 4      236374.39  1421.49          1290.85               0           0
# ...          ...      ...              ...             ...         ...
# 19995  236123.54  3572.34             0.00               0           0
# 19996  374572.72  3560.24             0.00               0           0
# 19997  279238.55   101.75             0.00               0           0
# 19998  149678.27   439.46           214.36               1           0
# 19999  265153.92   909.82             0.00               0           0
#
#        Delinquency  Utilization  Gender  Race  Approved
# 0                0     0.759069       1     0         1
# 1                1     0.402820       1     0         1
# 2                0     0.684272       1     1         1
# 3                0     0.037982       0     0         0
# 4                2     0.231110       1     1         1
# ...            ...          ...     ...   ...       ...
# 19995            0     0.896326       1     1         0
# 19996            0     0.648893       1     1         0
# 19997            0     0.068079       0     1         0
# 19998            2     0.311219       0     0         1
# 19999            0     0.300862       1     1         1
#
# [20000 rows x 10 columns]

# %%
# Data Preparation
exp.data_summary(feature_exclude=["Gender", "Race"], silent=True)
exp.data_prepare(target="Approved", task_type="classification", silent=True)
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…

# %%
# Build XGBoost model with max_depth 3
from xgboost import XGBClassifier
model = XGBClassifier(max_depth=3, n_estimators=1000,
                      learning_rate=0.01, random_state=0)
exp.model_train(model, name="XGB-default")
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(hidden_layer_sizes=[20]*4,
                      activation="relu", random_state=0)
exp.model_train(model, name='MLP-default')
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…

# %%
# Build benchmark models XGB2 and GAMI-Net

from piml.models import XGB2Classifier
from piml.models import GAMINetClassifier
exp.model_train(model=XGB2Classifier(n_estimators = 1000, eta = 0.01,
                                     mono_increasing_list=("Balance", ),
                                     mono_decreasing_list=("Utilization", )), name="XGB2")
exp.model_train(model=GAMINetClassifier(mono_increasing_list=("Balance", ),
                                     mono_decreasing_list=("Utilization", )), name="GAMI-Net")
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…

# %%
exp.model_compare(models=["XGB-default", "MLP-default", "XGB2", "GAMI-Net"], show="accuracy_plot", metric="ACC")
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…

# %% [markdown]
# ## 2) Prediction Accuracy

# %%
exp.model_diagnose(model="XGB-default", show='accuracy_table')
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
#            ACC      AUC       F1 LogLoss   Brier
#
# Train   0.7033   0.7722   0.7265  0.5676  0.1931
# Test    0.6890   0.7564   0.7153  0.5845  0.1997
# Gap    -0.0143  -0.0158  -0.0112  0.0169  0.0066

# %%
result = exp.segmented_diagnose(model="XGB-default", show="segment_table", segment_feature="Mortgage",
                       segment_method="uniform", segment_bins = 10, return_data=True)
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# <style type="text/css">
# #T_b23c2_row0_col0, #T_b23c2_row0_col1, #T_b23c2_row0_col2, #T_b23c2_row0_col3, #T_b23c2_row0_col4, #T_b23c2_row1_col0, #T_b23c2_row1_col1, #T_b23c2_row1_col2, #T_b23c2_row1_col3, #T_b23c2_row1_col4, #T_b23c2_row2_col0, #T_b23c2_row2_col1, #T_b23c2_row2_col2, #T_b23c2_row2_col3, #T_b23c2_row2_col4, #T_b23c2_row3_col0, #T_b23c2_row3_col1, #T_b23c2_row3_col2, #T_b23c2_row3_col3, #T_b23c2_row3_col4, #T_b23c2_row4_col0, #T_b23c2_row4_col1, #T_b23c2_row4_col2, #T_b23c2_row4_col3, #T_b23c2_row4_col4, #T_b23c2_row5_col0, #T_b23c2_row5_col1, #T_b23c2_row5_col2, #T_b23c2_row5_col3, #T_b23c2_row5_col4, #T_b23c2_row6_col0, #T_b23c2_row6_col1, #T_b23c2_row6_col2, #T_b23c2_row6_col3, #T_b23c2_row6_col4, #T_b23c2_row7_col0, #T_b23c2_row7_col1, #T_b23c2_row7_col2, #T_b23c2_row7_col3, #T_b23c2_row7_col4, #T_b23c2_row8_col0, #T_b23c2_row8_col1, #T_b23c2_row8_col2, #T_b23c2_row8_col3, #T_b23c2_row8_col4, #T_b23c2_row9_col0, #T_b23c2_row9_col1, #T_b23c2_row9_col2, #T_b23c2_row9_col3, #T_b23c2_row9_col4 {
#   width: 9em;
# }
# </style>
# <table id="T_b23c2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b23c2_level0_col0" class="col_heading level0 col0" >Segment ID</th>
#       <th id="T_b23c2_level0_col1" class="col_heading level0 col1" >Feature</th>
#       <th id="T_b23c2_level0_col2" class="col_heading level0 col2" >Segment</th>
#       <th id="T_b23c2_level0_col3" class="col_heading level0 col3" >Size</th>
#       <th id="T_b23c2_level0_col4" class="col_heading level0 col4" >ACC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b23c2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b23c2_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_b23c2_row0_col1" class="data row0 col1" >Mortgage</td>
#       <td id="T_b23c2_row0_col2" class="data row0 col2" >[0.6005, 0.6668]</td>
#       <td id="T_b23c2_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_b23c2_row0_col4" class="data row0 col4" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_b23c2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b23c2_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_b23c2_row1_col1" class="data row1 col1" >Mortgage</td>
#       <td id="T_b23c2_row1_col2" class="data row1 col2" >[0.5343, 0.6005)</td>
#       <td id="T_b23c2_row1_col3" class="data row1 col3" >6</td>
#       <td id="T_b23c2_row1_col4" class="data row1 col4" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_b23c2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b23c2_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_b23c2_row2_col1" class="data row2 col1" >Mortgage</td>
#       <td id="T_b23c2_row2_col2" class="data row2 col2" >[0.0042, 0.0705)</td>
#       <td id="T_b23c2_row2_col3" class="data row2 col3" >1279</td>
#       <td id="T_b23c2_row2_col4" class="data row2 col4" >0.641908</td>
#     </tr>
#     <tr>
#       <th id="T_b23c2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b23c2_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_b23c2_row3_col1" class="data row3 col1" >Mortgage</td>
#       <td id="T_b23c2_row3_col2" class="data row3 col2" >[0.0705, 0.1367)</td>
#       <td id="T_b23c2_row3_col3" class="data row3 col3" >1373</td>
#       <td id="T_b23c2_row3_col4" class="data row3 col4" >0.690459</td>
#     </tr>
#     <tr>
#       <th id="T_b23c2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b23c2_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_b23c2_row4_col1" class="data row4 col1" >Mortgage</td>
#       <td id="T_b23c2_row4_col2" class="data row4 col2" >[0.1367, 0.203)</td>
#       <td id="T_b23c2_row4_col3" class="data row4 col3" >770</td>
#       <td id="T_b23c2_row4_col4" class="data row4 col4" >0.716883</td>
#     </tr>
#     <tr>
#       <th id="T_b23c2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b23c2_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_b23c2_row5_col1" class="data row5 col1" >Mortgage</td>
#       <td id="T_b23c2_row5_col2" class="data row5 col2" >[0.203, 0.2693)</td>
#       <td id="T_b23c2_row5_col3" class="data row5 col3" >335</td>
#       <td id="T_b23c2_row5_col4" class="data row5 col4" >0.740299</td>
#     </tr>
#     <tr>
#       <th id="T_b23c2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b23c2_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_b23c2_row6_col1" class="data row6 col1" >Mortgage</td>
#       <td id="T_b23c2_row6_col2" class="data row6 col2" >[0.2693, 0.3355)</td>
#       <td id="T_b23c2_row6_col3" class="data row6 col3" >141</td>
#       <td id="T_b23c2_row6_col4" class="data row6 col4" >0.758865</td>
#     </tr>
#     <tr>
#       <th id="T_b23c2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b23c2_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_b23c2_row7_col1" class="data row7 col1" >Mortgage</td>
#       <td id="T_b23c2_row7_col2" class="data row7 col2" >[0.468, 0.5343)</td>
#       <td id="T_b23c2_row7_col3" class="data row7 col3" >9</td>
#       <td id="T_b23c2_row7_col4" class="data row7 col4" >0.777778</td>
#     </tr>
#     <tr>
#       <th id="T_b23c2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b23c2_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_b23c2_row8_col1" class="data row8 col1" >Mortgage</td>
#       <td id="T_b23c2_row8_col2" class="data row8 col2" >[0.3355, 0.4018)</td>
#       <td id="T_b23c2_row8_col3" class="data row8 col3" >56</td>
#       <td id="T_b23c2_row8_col4" class="data row8 col4" >0.785714</td>
#     </tr>
#     <tr>
#       <th id="T_b23c2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b23c2_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_b23c2_row9_col1" class="data row9 col1" >Mortgage</td>
#       <td id="T_b23c2_row9_col2" class="data row9 col2" >[0.4018, 0.468)</td>
#       <td id="T_b23c2_row9_col3" class="data row9 col3" >29</td>
#       <td id="T_b23c2_row9_col4" class="data row9 col4" >0.862069</td>
#     </tr>
#   </tbody>
# </table>

# %%
result = exp.segmented_diagnose(model="XGB-default", show="segment_table", segment_feature="Mortgage",
                       segment_method="quantile", segment_bins = 10, return_data=True)
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# <style type="text/css">
# #T_61a82_row0_col0, #T_61a82_row0_col1, #T_61a82_row0_col2, #T_61a82_row0_col3, #T_61a82_row0_col4, #T_61a82_row1_col0, #T_61a82_row1_col1, #T_61a82_row1_col2, #T_61a82_row1_col3, #T_61a82_row1_col4, #T_61a82_row2_col0, #T_61a82_row2_col1, #T_61a82_row2_col2, #T_61a82_row2_col3, #T_61a82_row2_col4, #T_61a82_row3_col0, #T_61a82_row3_col1, #T_61a82_row3_col2, #T_61a82_row3_col3, #T_61a82_row3_col4, #T_61a82_row4_col0, #T_61a82_row4_col1, #T_61a82_row4_col2, #T_61a82_row4_col3, #T_61a82_row4_col4, #T_61a82_row5_col0, #T_61a82_row5_col1, #T_61a82_row5_col2, #T_61a82_row5_col3, #T_61a82_row5_col4, #T_61a82_row6_col0, #T_61a82_row6_col1, #T_61a82_row6_col2, #T_61a82_row6_col3, #T_61a82_row6_col4, #T_61a82_row7_col0, #T_61a82_row7_col1, #T_61a82_row7_col2, #T_61a82_row7_col3, #T_61a82_row7_col4, #T_61a82_row8_col0, #T_61a82_row8_col1, #T_61a82_row8_col2, #T_61a82_row8_col3, #T_61a82_row8_col4, #T_61a82_row9_col0, #T_61a82_row9_col1, #T_61a82_row9_col2, #T_61a82_row9_col3, #T_61a82_row9_col4 {
#   width: 9em;
# }
# </style>
# <table id="T_61a82" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61a82_level0_col0" class="col_heading level0 col0" >Segment ID</th>
#       <th id="T_61a82_level0_col1" class="col_heading level0 col1" >Feature</th>
#       <th id="T_61a82_level0_col2" class="col_heading level0 col2" >Segment</th>
#       <th id="T_61a82_level0_col3" class="col_heading level0 col3" >Size</th>
#       <th id="T_61a82_level0_col4" class="col_heading level0 col4" >ACC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61a82_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61a82_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_61a82_row0_col1" class="data row0 col1" >Mortgage</td>
#       <td id="T_61a82_row0_col2" class="data row0 col2" >[0.0042, 0.0335)</td>
#       <td id="T_61a82_row0_col3" class="data row0 col3" >400</td>
#       <td id="T_61a82_row0_col4" class="data row0 col4" >0.635000</td>
#     </tr>
#     <tr>
#       <th id="T_61a82_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_61a82_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_61a82_row1_col1" class="data row1 col1" >Mortgage</td>
#       <td id="T_61a82_row1_col2" class="data row1 col2" >[0.0501, 0.0664)</td>
#       <td id="T_61a82_row1_col3" class="data row1 col3" >400</td>
#       <td id="T_61a82_row1_col4" class="data row1 col4" >0.640000</td>
#     </tr>
#     <tr>
#       <th id="T_61a82_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_61a82_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_61a82_row2_col1" class="data row2 col1" >Mortgage</td>
#       <td id="T_61a82_row2_col2" class="data row2 col2" >[0.0335, 0.0501)</td>
#       <td id="T_61a82_row2_col3" class="data row2 col3" >400</td>
#       <td id="T_61a82_row2_col4" class="data row2 col4" >0.652500</td>
#     </tr>
#     <tr>
#       <th id="T_61a82_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_61a82_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_61a82_row3_col1" class="data row3 col1" >Mortgage</td>
#       <td id="T_61a82_row3_col2" class="data row3 col2" >[0.0664, 0.0841)</td>
#       <td id="T_61a82_row3_col3" class="data row3 col3" >400</td>
#       <td id="T_61a82_row3_col4" class="data row3 col4" >0.652500</td>
#     </tr>
#     <tr>
#       <th id="T_61a82_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_61a82_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_61a82_row4_col1" class="data row4 col1" >Mortgage</td>
#       <td id="T_61a82_row4_col2" class="data row4 col2" >[0.0841, 0.1016)</td>
#       <td id="T_61a82_row4_col3" class="data row4 col3" >400</td>
#       <td id="T_61a82_row4_col4" class="data row4 col4" >0.677500</td>
#     </tr>
#     <tr>
#       <th id="T_61a82_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_61a82_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_61a82_row5_col1" class="data row5 col1" >Mortgage</td>
#       <td id="T_61a82_row5_col2" class="data row5 col2" >[0.1465, 0.1782)</td>
#       <td id="T_61a82_row5_col3" class="data row5 col3" >400</td>
#       <td id="T_61a82_row5_col4" class="data row5 col4" >0.690000</td>
#     </tr>
#     <tr>
#       <th id="T_61a82_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_61a82_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_61a82_row6_col1" class="data row6 col1" >Mortgage</td>
#       <td id="T_61a82_row6_col2" class="data row6 col2" >[0.1216, 0.1465)</td>
#       <td id="T_61a82_row6_col3" class="data row6 col3" >400</td>
#       <td id="T_61a82_row6_col4" class="data row6 col4" >0.715000</td>
#     </tr>
#     <tr>
#       <th id="T_61a82_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_61a82_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_61a82_row7_col1" class="data row7 col1" >Mortgage</td>
#       <td id="T_61a82_row7_col2" class="data row7 col2" >[0.1016, 0.1216)</td>
#       <td id="T_61a82_row7_col3" class="data row7 col3" >400</td>
#       <td id="T_61a82_row7_col4" class="data row7 col4" >0.727500</td>
#     </tr>
#     <tr>
#       <th id="T_61a82_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_61a82_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_61a82_row8_col1" class="data row8 col1" >Mortgage</td>
#       <td id="T_61a82_row8_col2" class="data row8 col2" >[0.1782, 0.2317)</td>
#       <td id="T_61a82_row8_col3" class="data row8 col3" >400</td>
#       <td id="T_61a82_row8_col4" class="data row8 col4" >0.730000</td>
#     </tr>
#     <tr>
#       <th id="T_61a82_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_61a82_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_61a82_row9_col1" class="data row9 col1" >Mortgage</td>
#       <td id="T_61a82_row9_col2" class="data row9 col2" >[0.2317, 0.6668]</td>
#       <td id="T_61a82_row9_col3" class="data row9 col3" >400</td>
#       <td id="T_61a82_row9_col4" class="data row9 col4" >0.770000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Automatic segmentation through XGB1 surrogate modeling (|residual| ~ x1)
result = exp.segmented_diagnose(model="XGB-default", show="segment_table", segment_feature="Utilization",
                       segment_method="auto", return_data=True)
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# <style type="text/css">
# #T_4a9de_row0_col0, #T_4a9de_row0_col1, #T_4a9de_row0_col2, #T_4a9de_row0_col3, #T_4a9de_row0_col4, #T_4a9de_row1_col0, #T_4a9de_row1_col1, #T_4a9de_row1_col2, #T_4a9de_row1_col3, #T_4a9de_row1_col4, #T_4a9de_row2_col0, #T_4a9de_row2_col1, #T_4a9de_row2_col2, #T_4a9de_row2_col3, #T_4a9de_row2_col4, #T_4a9de_row3_col0, #T_4a9de_row3_col1, #T_4a9de_row3_col2, #T_4a9de_row3_col3, #T_4a9de_row3_col4, #T_4a9de_row4_col0, #T_4a9de_row4_col1, #T_4a9de_row4_col2, #T_4a9de_row4_col3, #T_4a9de_row4_col4, #T_4a9de_row5_col0, #T_4a9de_row5_col1, #T_4a9de_row5_col2, #T_4a9de_row5_col3, #T_4a9de_row5_col4, #T_4a9de_row6_col0, #T_4a9de_row6_col1, #T_4a9de_row6_col2, #T_4a9de_row6_col3, #T_4a9de_row6_col4, #T_4a9de_row7_col0, #T_4a9de_row7_col1, #T_4a9de_row7_col2, #T_4a9de_row7_col3, #T_4a9de_row7_col4 {
#   width: 9em;
# }
# </style>
# <table id="T_4a9de" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a9de_level0_col0" class="col_heading level0 col0" >Segment ID</th>
#       <th id="T_4a9de_level0_col1" class="col_heading level0 col1" >Feature</th>
#       <th id="T_4a9de_level0_col2" class="col_heading level0 col2" >Segment</th>
#       <th id="T_4a9de_level0_col3" class="col_heading level0 col3" >Size</th>
#       <th id="T_4a9de_level0_col4" class="col_heading level0 col4" >ACC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a9de_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a9de_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_4a9de_row0_col1" class="data row0 col1" >Utilization</td>
#       <td id="T_4a9de_row0_col2" class="data row0 col2" >[0.2221, 0.3114)</td>
#       <td id="T_4a9de_row0_col3" class="data row0 col3" >547</td>
#       <td id="T_4a9de_row0_col4" class="data row0 col4" >0.632541</td>
#     </tr>
#     <tr>
#       <th id="T_4a9de_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a9de_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_4a9de_row1_col1" class="data row1 col1" >Utilization</td>
#       <td id="T_4a9de_row1_col2" class="data row1 col2" >[-inf, 0.2221)</td>
#       <td id="T_4a9de_row1_col3" class="data row1 col3" >1000</td>
#       <td id="T_4a9de_row1_col4" class="data row1 col4" >0.651000</td>
#     </tr>
#     <tr>
#       <th id="T_4a9de_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4a9de_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_4a9de_row2_col1" class="data row2 col1" >Utilization</td>
#       <td id="T_4a9de_row2_col2" class="data row2 col2" >[0.3114, 0.3928)</td>
#       <td id="T_4a9de_row2_col3" class="data row2 col3" >391</td>
#       <td id="T_4a9de_row2_col4" class="data row2 col4" >0.680307</td>
#     </tr>
#     <tr>
#       <th id="T_4a9de_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4a9de_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_4a9de_row3_col1" class="data row3 col1" >Utilization</td>
#       <td id="T_4a9de_row3_col2" class="data row3 col2" >[0.5101, 0.8987)</td>
#       <td id="T_4a9de_row3_col3" class="data row3 col3" >1202</td>
#       <td id="T_4a9de_row3_col4" class="data row3 col4" >0.713810</td>
#     </tr>
#     <tr>
#       <th id="T_4a9de_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4a9de_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_4a9de_row4_col1" class="data row4 col1" >Utilization</td>
#       <td id="T_4a9de_row4_col2" class="data row4 col2" >[0.4565, 0.5101)</td>
#       <td id="T_4a9de_row4_col3" class="data row4 col3" >188</td>
#       <td id="T_4a9de_row4_col4" class="data row4 col4" >0.718085</td>
#     </tr>
#     <tr>
#       <th id="T_4a9de_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4a9de_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_4a9de_row5_col1" class="data row5 col1" >Utilization</td>
#       <td id="T_4a9de_row5_col2" class="data row5 col2" >[0.3928, 0.4565)</td>
#       <td id="T_4a9de_row5_col3" class="data row5 col3" >234</td>
#       <td id="T_4a9de_row5_col4" class="data row5 col4" >0.722222</td>
#     </tr>
#     <tr>
#       <th id="T_4a9de_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4a9de_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_4a9de_row6_col1" class="data row6 col1" >Utilization</td>
#       <td id="T_4a9de_row6_col2" class="data row6 col2" >[0.8987, 0.9904)</td>
#       <td id="T_4a9de_row6_col3" class="data row6 col3" >391</td>
#       <td id="T_4a9de_row6_col4" class="data row6 col4" >0.749361</td>
#     </tr>
#     <tr>
#       <th id="T_4a9de_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4a9de_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_4a9de_row7_col1" class="data row7 col1" >Utilization</td>
#       <td id="T_4a9de_row7_col2" class="data row7 col2" >[0.9904, inf]</td>
#       <td id="T_4a9de_row7_col3" class="data row7 col3" >47</td>
#       <td id="T_4a9de_row7_col4" class="data row7 col4" >0.808511</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Joint segmentation (shown top 10 worst performing segments) (|residual| ~ x1 + x2 + ... )
result = exp.segmented_diagnose(model="XGB-default", show="segment_table",
                                segment_method="auto", metric="ACC",
                                return_data=True)
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# <style type="text/css">
# #T_9c55d_row0_col0, #T_9c55d_row0_col1, #T_9c55d_row0_col2, #T_9c55d_row0_col3, #T_9c55d_row0_col4, #T_9c55d_row1_col0, #T_9c55d_row1_col1, #T_9c55d_row1_col2, #T_9c55d_row1_col3, #T_9c55d_row1_col4, #T_9c55d_row2_col0, #T_9c55d_row2_col1, #T_9c55d_row2_col2, #T_9c55d_row2_col3, #T_9c55d_row2_col4, #T_9c55d_row3_col0, #T_9c55d_row3_col1, #T_9c55d_row3_col2, #T_9c55d_row3_col3, #T_9c55d_row3_col4, #T_9c55d_row4_col0, #T_9c55d_row4_col1, #T_9c55d_row4_col2, #T_9c55d_row4_col3, #T_9c55d_row4_col4, #T_9c55d_row5_col0, #T_9c55d_row5_col1, #T_9c55d_row5_col2, #T_9c55d_row5_col3, #T_9c55d_row5_col4, #T_9c55d_row6_col0, #T_9c55d_row6_col1, #T_9c55d_row6_col2, #T_9c55d_row6_col3, #T_9c55d_row6_col4, #T_9c55d_row7_col0, #T_9c55d_row7_col1, #T_9c55d_row7_col2, #T_9c55d_row7_col3, #T_9c55d_row7_col4, #T_9c55d_row8_col0, #T_9c55d_row8_col1, #T_9c55d_row8_col2, #T_9c55d_row8_col3, #T_9c55d_row8_col4, #T_9c55d_row9_col0, #T_9c55d_row9_col1, #T_9c55d_row9_col2, #T_9c55d_row9_col3, #T_9c55d_row9_col4 {
#   width: 9em;
# }
# </style>
# <table id="T_9c55d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c55d_level0_col0" class="col_heading level0 col0" >Segment ID</th>
#       <th id="T_9c55d_level0_col1" class="col_heading level0 col1" >Feature</th>
#       <th id="T_9c55d_level0_col2" class="col_heading level0 col2" >Segment</th>
#       <th id="T_9c55d_level0_col3" class="col_heading level0 col3" >Size</th>
#       <th id="T_9c55d_level0_col4" class="col_heading level0 col4" >ACC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c55d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c55d_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9c55d_row0_col1" class="data row0 col1" >Balance</td>
#       <td id="T_9c55d_row0_col2" class="data row0 col2" >[0.1811, 0.2043)</td>
#       <td id="T_9c55d_row0_col3" class="data row0 col3" >64</td>
#       <td id="T_9c55d_row0_col4" class="data row0 col4" >0.562500</td>
#     </tr>
#     <tr>
#       <th id="T_9c55d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9c55d_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_9c55d_row1_col1" class="data row1 col1" >Balance</td>
#       <td id="T_9c55d_row1_col2" class="data row1 col2" >[0.0069, 0.011)</td>
#       <td id="T_9c55d_row1_col3" class="data row1 col3" >281</td>
#       <td id="T_9c55d_row1_col4" class="data row1 col4" >0.565836</td>
#     </tr>
#     <tr>
#       <th id="T_9c55d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9c55d_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_9c55d_row2_col1" class="data row2 col1" >Mortgage</td>
#       <td id="T_9c55d_row2_col2" class="data row2 col2" >[-inf, 0.014)</td>
#       <td id="T_9c55d_row2_col3" class="data row2 col3" >48</td>
#       <td id="T_9c55d_row2_col4" class="data row2 col4" >0.604167</td>
#     </tr>
#     <tr>
#       <th id="T_9c55d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9c55d_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_9c55d_row3_col1" class="data row3 col1" >Mortgage</td>
#       <td id="T_9c55d_row3_col2" class="data row3 col2" >[0.0526, 0.0644)</td>
#       <td id="T_9c55d_row3_col3" class="data row3 col3" >281</td>
#       <td id="T_9c55d_row3_col4" class="data row3 col4" >0.608541</td>
#     </tr>
#     <tr>
#       <th id="T_9c55d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9c55d_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_9c55d_row4_col1" class="data row4 col1" >Utilization</td>
#       <td id="T_9c55d_row4_col2" class="data row4 col2" >[0.2221, 0.3114)</td>
#       <td id="T_9c55d_row4_col3" class="data row4 col3" >547</td>
#       <td id="T_9c55d_row4_col4" class="data row4 col4" >0.632541</td>
#     </tr>
#     <tr>
#       <th id="T_9c55d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9c55d_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_9c55d_row5_col1" class="data row5 col1" >Mortgage</td>
#       <td id="T_9c55d_row5_col2" class="data row5 col2" >[0.0665, 0.0723)</td>
#       <td id="T_9c55d_row5_col3" class="data row5 col3" >125</td>
#       <td id="T_9c55d_row5_col4" class="data row5 col4" >0.640000</td>
#     </tr>
#     <tr>
#       <th id="T_9c55d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9c55d_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_9c55d_row6_col1" class="data row6 col1" >Mortgage</td>
#       <td id="T_9c55d_row6_col2" class="data row6 col2" >[0.0391, 0.0526)</td>
#       <td id="T_9c55d_row6_col3" class="data row6 col3" >343</td>
#       <td id="T_9c55d_row6_col4" class="data row6 col4" >0.644315</td>
#     </tr>
#     <tr>
#       <th id="T_9c55d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9c55d_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_9c55d_row7_col1" class="data row7 col1" >Mortgage</td>
#       <td id="T_9c55d_row7_col2" class="data row7 col2" >[0.0723, 0.0885)</td>
#       <td id="T_9c55d_row7_col3" class="data row7 col3" >376</td>
#       <td id="T_9c55d_row7_col4" class="data row7 col4" >0.648936</td>
#     </tr>
#     <tr>
#       <th id="T_9c55d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9c55d_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_9c55d_row8_col1" class="data row8 col1" >Utilization</td>
#       <td id="T_9c55d_row8_col2" class="data row8 col2" >[-inf, 0.2221)</td>
#       <td id="T_9c55d_row8_col3" class="data row8 col3" >1000</td>
#       <td id="T_9c55d_row8_col4" class="data row8 col4" >0.651000</td>
#     </tr>
#     <tr>
#       <th id="T_9c55d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9c55d_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_9c55d_row9_col1" class="data row9 col1" >Balance</td>
#       <td id="T_9c55d_row9_col2" class="data row9 col2" >[-inf, 0.0069)</td>
#       <td id="T_9c55d_row9_col3" class="data row9 col3" >298</td>
#       <td id="T_9c55d_row9_col4" class="data row9 col4" >0.651007</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3) Weakness Detection

# %%
# Choose XGB-default: WeakSpot, 1D (Delinquency) with ACC/Threshold 1.0; 2D (Deliquency, Utilization) with ACC/Threshold 1.1
exp.model_diagnose()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# VBox(children=(Dropdown(layout=Layout(width='20%'), options=('Select Model', 'XGB-default'), style=Description…

# %% [markdown]
# ## 4) Overfitting Analysis

# %%
# Benign Overfitting Phenomenon
import pandas as pd
import numpy as np
from matplotlib import pylab as plt
from sklearn.metrics import roc_auc_score

feature_names = exp.get_feature_names()
target_name = exp.get_target_name()ridr
train_x, train_y, _ = exp.get_data(train=True)
test_x, test_y, _ = exp.get_data(test=True)

def score(model, iteration_range):
    train_auc = roc_auc_score(train_y, model.predict_proba(train_x, iteration_range=iteration_range)[:, 1])
    test_auc = roc_auc_score(test_y, model.predict_proba(test_x, iteration_range=iteration_range)[:, 1])
    tree_idx = np.logical_and(xgbinfo["Tree"] < iteration_range[1], xgbinfo["Tree"] >= iteration_range[0])
    n_leaves = np.sum(xgbinfo[tree_idx].loc[:, ["Feature"]].values == "Leaf")
    return {'n_leaves': n_leaves, 'n_iteration': iteration_range[1], 'train_auc': train_auc, 'test_auc': test_auc}

all_metrics = []
model = exp.get_model("XGB-default").estimator
xgbinfo = model.get_booster().trees_to_dataframe()
for i in range(0, model.get_num_boosting_rounds(), 5):
    metrics = score(model, (0, i + 1))
    all_metrics.append(metrics)
all_resluts = pd.DataFrame(all_metrics)
all_resluts = pd.DataFrame(all_metrics)

# %%
plt.figure(figsize=(8,5))
plt.scatter(all_resluts["n_iteration"], all_resluts["train_auc"], label="train", color="blue", s=5)
plt.scatter(all_resluts["n_iteration"], all_resluts["test_auc"], label="test", color="red",  s=5)
plt.legend()
plt.ylabel("AUC")
plt.xlabel("n_iteration")
plt.title("Benign Overfitting: Tendency Toward Overparametrized Models")
plt.show()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…

# %%
# Choose XGB-default, XGB2, GAMI-Net: Overfit (Delinquency, AUC)
exp.model_compare()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# VBox(children=(HBox(children=(Dropdown(layout=Layout(width='30%'), options=('Select Model', 'XGB-default', 'XG…

# %% [markdown]
# ## 5) Prediction Uncertainty

# %%
# Choose XGB-default, Reliablity: Bandwidth Threshold = 1
exp.model_diagnose()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# VBox(children=(Dropdown(layout=Layout(width='20%'), options=('Select Model', 'XGB-default', 'XGB2', 'GAMI-Net'…

# %% [markdown]
# ## 6) Robustness Test

# %%
# Choose XGB-default, XGB2, GAMI-Net: Overfit (Delinquency, AUC)
exp.model_compare()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# VBox(children=(HBox(children=(Dropdown(layout=Layout(width='30%'), options=('Select Model', 'XGB-default', 'XG…

# %% [markdown]
# ## 7) Reslience Test

# %%
# Choose XGB-default, Reliablity: Bandwidth Threshold = 1
exp.model_diagnose()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# VBox(children=(Dropdown(layout=Layout(width='20%'), options=('Select Model', 'XGB-default', 'XGB2', 'GAMI-Net'…

# %% [markdown]
# ## 8) Bias and Fairness

# %%
exp.model_fairness_compare()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# VBox(children=(HBox(children=(Dropdown(layout=Layout(width='30%'), options=('Select Model', 'XGB-default', 'XG…

# %%
exp.model_fairness()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# VBox(children=(Dropdown(layout=Layout(width='20%'), options=('Select Model', 'XGB-default', 'XGB2', 'GAMI-Net'…
