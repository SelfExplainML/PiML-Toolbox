# %% [markdown]
# # PiML Toolbox: Low-code Demo for TaiwanCredit Data
#
# This example notebook demonstrates how to use PiML in its low-code mode for developing machine learning models for the TaiwanCredit data from UCI repository, which consists of 30,000 credit card clients in Taiwan from 200504 to 200509; see details [here](https://archive.ics.uci.edu/ml/datasets/default+of+credit+card+clients). The data can be loaded from PiML and it is subject to slight preprocessing.
#
# The response `FlagDefault` is binary and it is a classification problem.

# %% [markdown]
# # Stage 0: Install PiML package on Google Colab
#
# 1. Run `!pip install piml` to install the latest version of PiML
# 2. In Colab, you'll need restart the runtime in order to use newly installed PiML version.

# %%
# !pip install PiML

# %%
# !pip install statsmodels -U # install version>=0.13 to get more stable curve fit in some plots

# %% [markdown]
# # Stage 1: Initialize an experiment, Load and Prepare data <a name="expdata"></a>

# %%
from piml import Experiment
exp = Experiment(platform="colab")

# %%
# Choose TaiwanCredit
exp.data_loader()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# VBox(children=(Dropdown(layout=Layout(width='20%'), options=('Select Data', 'CoCircles', 'Friedman', 'BikeShar…

# %%
# Use only payment history attributes: Pay_1~6, BILL_AMT1~6 and PAY_AMT1~6 (i.e., exclude all others but keep the response `FlagDefault`); 
exp.data_summary()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# HTML(value='<link rel="stylesheet" href="//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.…
# VBox(children=(HTML(value='Data Shape:(30000, 24)'), Tab(children=(Output(), Output()), _dom_classes=('data-su…

# %%
exp.data_prepare()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# VBox(children=(HBox(children=(VBox(children=(HTML(value='<p>Target Variable:</p>'), HTML(value='<p>Sample Weig…

# %%
exp.feature_select()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# VBox(children=(HBox(children=(VBox(children=(HTML(value='<p>Top Percentage:</p>'),), layout=Layout(width='100p…

# %%
exp.eda()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# HBox(children=(VBox(children=(HTML(value='<h4>Univariate:</h4>'), HBox(children=(Dropdown(layout=Layout(width=…

# %% [markdown]
# # Stage 2. Train intepretable models <a name="modeltrain"></a>

# %%
# Choose EBM, GAMI-Net and ReLU-DNN (customize ReLU-DNN with L1_regularization = `0.0008`), click "RUN" to train; 
# When training is finished, register the three trained models one by one.
exp.model_train()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css">
# VBox(children=(Box(children=(Box(children=(HTML(value="<h4 style='margin: 10px 0px;'>Choose Model</h4>"), Box(…

# %% [markdown]
# # Stage 3. Explain and Interpret<a name="modelinterpret"></a>

# %%
# Model-agnostic post-hoc explanation by Permutation Feature Importance, PDP (1D and 2D) vs. ALE (1D and 2D), LIME vs. SHAP
exp.model_explain()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# VBox(children=(Dropdown(layout=Layout(width='20%'), options=('Select Model', 'EBM', 'GAMI-Net', 'ReLU-DNN'), s…

# %%
# Model-specific inherent interpretation including feature importance, main effects and pairwise interactions.
exp.model_interpret()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# VBox(children=(Dropdown(layout=Layout(width='20%'), options=('Select Model', 'EBM', 'GAMI-Net', 'ReLU-DNN'), s…

# %% [markdown]
# # Stage 4. Diagnose and Compare

# %%
exp.model_diagnose()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# VBox(children=(Dropdown(layout=Layout(width='20%'), options=('Select Model', 'EBM', 'GAMI-Net', 'ReLU-DNN'), s…

# %%
# Choose ReLU-DNN, EBM and GAMI-Net
exp.model_compare()
# Out:
# HTML(value='\n        <style>\n\n        .left-label {\n            width: 30%;\n        }\n\n        .card-pa…
# VBox(children=(HBox(children=(Dropdown(layout=Layout(width='30%'), options=('Select Model', 'EBM', 'GAMI-Net',…
